# %%
# STORE DATA SET

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
# Import data set
df = pd.read_csv("Store_Management_System.csv")
df
# Out:
#     Order ID  Order Date   Ship Date Customer ID     Customer Name  \
# 0    ORD1000  2024-07-29  2024-08-02     CUST959    Kimberly Ortiz
# 1    ORD1001  2024-11-16  2024-11-19     CUST324       Robert Diaz
# 2    ORD1002  2025-04-29  2025-05-04     CUST934       Steven Ward
# 3    ORD1003  2025-10-07  2025-10-08     CUST323   Cynthia Dunn MD
# 4    ORD1004  2024-11-28  2024-12-04     CUST911     Joseph Harper
# ..       ...         ...         ...         ...               ...
# 995  ORD1995  2024-12-11  2024-12-12     CUST662     Alexis Hooper
# 996  ORD1996  2024-04-08  2024-04-10     CUST792      Andre Brewer
# 997  ORD1997  2025-03-14  2025-03-16     CUST364     Sherri Cooper
# 998  ORD1998  2025-10-29  2025-10-30     CUST124  Mrs. Jamie Nunez
# 999  ORD1999  2025-12-24  2025-12-28     CUST642   Michelle Miller
#
#     Customer Segment Product ID  Product Name         Category Region  ...  \
# 0       House Office   PROD2927      Notebook  Office Supplies   East  ...
# 1          Corporate   PROD2378           Pen  Office Supplies   West  ...
# 2       House Office   PROD4007   File Folder  Office Supplies   West  ...
# 3       House Office   PROD1508       Monitor      Electronics  North  ...
# 4           Consumer   PROD2159   Cooking Oil          Grocery  South  ...
# ..               ...        ...           ...              ...    ...  ...
# 995         Consumer   PROD7325         Sugar          Grocery   West  ...
# 996     House Office   PROD5144  Office Chair        Furniture   West  ...
# 997         Consumer   PROD4761          Sofa        Furniture  South  ...
# 998         Consumer   PROD9335  Dining Table        Furniture  North  ...
# 999         Consumer   PROD2674          Sofa        Furniture  South  ...
#
#     Sales Amount Cost Price   Profit  Payment Mode  Delivery Status  \
# 0         5521.6    4947.54   574.06           UPI         Returned
# 1        13004.8   11639.88  1364.92   Credit Card        Delivered
# 2        17623.2   14226.61  3396.59   Credit Card        Cancelled
# 3        14883.2   12205.65  2677.55   Credit Card         Returned
# 4         2664.0    1672.74   991.26          Cash        Cancelled
# ..           ...        ...      ...           ...              ...
# 995       9810.0    6489.74  3320.26          Cash        Delivered
# 996       4504.5    3235.12  1269.38           UPI        Cancelled
# 997       3121.2    1904.19  1217.01   Credit Card          Pending
# 998       2756.0    2304.88   451.12           UPI          Pending
# 999       4348.8    3379.73   969.07          Cash        Delivered
#
#                    Supplier Name                    Supplier Email  \
# 0                    Diaz-Foster    stewartjohn@johnson-moore.info
# 1             Fernandez and Sons         njacobs@mullins-white.com
# 2                Garcia-Martinez        jameskim@montes-gibbs.info
# 3    Figueroa, Kaufman and Baker                  fmorris@ray.info
# 4                      Mann-Luna  mcdonaldmelinda@miller-diaz.info
# ..                           ...                               ...
# 995    Mccoy, Austin and Padilla        gibsonjohn@woods-stone.org
# 996      Porter, Floyd and Craig             anthony50@jackson.com
# 997                Carroll Group           ugray@johnson-white.biz
# 998                    Lopez LLC     snydermegan@morris-hinton.com
# 999                 Cox and Sons             margaret05@hanson.com
#
#      Stock Left Auto Reorder Reorder Quantity
# 0            18           NO                0
# 1            23           NO                0
# 2            38           NO                0
# 3            30           NO                0
# 4            11           NO                0
# ..          ...          ...              ...
# 995          15           NO                0
# 996          41           NO                0
# 997          50           NO                0
# 998          20           NO                0
# 999          17           NO                0
#
# [1000 rows x 25 columns]

# %%
# Basic Analysis

# %%
# Finding head
df.head()
# Out:
#   Order ID  Order Date   Ship Date Customer ID    Customer Name  \
# 0  ORD1000  2024-07-29  2024-08-02     CUST959   Kimberly Ortiz
# 1  ORD1001  2024-11-16  2024-11-19     CUST324      Robert Diaz
# 2  ORD1002  2025-04-29  2025-05-04     CUST934      Steven Ward
# 3  ORD1003  2025-10-07  2025-10-08     CUST323  Cynthia Dunn MD
# 4  ORD1004  2024-11-28  2024-12-04     CUST911    Joseph Harper
#
#   Customer Segment Product ID Product Name         Category Region  ...  \
# 0     House Office   PROD2927     Notebook  Office Supplies   East  ...
# 1        Corporate   PROD2378          Pen  Office Supplies   West  ...
# 2     House Office   PROD4007  File Folder  Office Supplies   West  ...
# 3     House Office   PROD1508      Monitor      Electronics  North  ...
# 4         Consumer   PROD2159  Cooking Oil          Grocery  South  ...
#
#   Sales Amount Cost Price   Profit  Payment Mode  Delivery Status  \
# 0       5521.6    4947.54   574.06           UPI         Returned
# 1      13004.8   11639.88  1364.92   Credit Card        Delivered
# 2      17623.2   14226.61  3396.59   Credit Card        Cancelled
# 3      14883.2   12205.65  2677.55   Credit Card         Returned
# 4       2664.0    1672.74   991.26          Cash        Cancelled
#
#                  Supplier Name                    Supplier Email  Stock Left  \
# 0                  Diaz-Foster    stewartjohn@johnson-moore.info          18
# 1           Fernandez and Sons         njacobs@mullins-white.com          23
# 2              Garcia-Martinez        jameskim@montes-gibbs.info          38
# 3  Figueroa, Kaufman and Baker                  fmorris@ray.info          30
# 4                    Mann-Luna  mcdonaldmelinda@miller-diaz.info          11
#
#   Auto Reorder Reorder Quantity
# 0           NO                0
# 1           NO                0
# 2           NO                0
# 3           NO                0
# 4           NO                0
#
# [5 rows x 25 columns]

# %%
# Finding Tail
df.tail()
# Out:
#     Order ID  Order Date   Ship Date Customer ID     Customer Name  \
# 995  ORD1995  2024-12-11  2024-12-12     CUST662     Alexis Hooper
# 996  ORD1996  2024-04-08  2024-04-10     CUST792      Andre Brewer
# 997  ORD1997  2025-03-14  2025-03-16     CUST364     Sherri Cooper
# 998  ORD1998  2025-10-29  2025-10-30     CUST124  Mrs. Jamie Nunez
# 999  ORD1999  2025-12-24  2025-12-28     CUST642   Michelle Miller
#
#     Customer Segment Product ID  Product Name   Category Region  ...  \
# 995         Consumer   PROD7325         Sugar    Grocery   West  ...
# 996     House Office   PROD5144  Office Chair  Furniture   West  ...
# 997         Consumer   PROD4761          Sofa  Furniture  South  ...
# 998         Consumer   PROD9335  Dining Table  Furniture  North  ...
# 999         Consumer   PROD2674          Sofa  Furniture  South  ...
#
#     Sales Amount Cost Price   Profit  Payment Mode  Delivery Status  \
# 995       9810.0    6489.74  3320.26          Cash        Delivered
# 996       4504.5    3235.12  1269.38           UPI        Cancelled
# 997       3121.2    1904.19  1217.01   Credit Card          Pending
# 998       2756.0    2304.88   451.12           UPI          Pending
# 999       4348.8    3379.73   969.07          Cash        Delivered
#
#                  Supplier Name                 Supplier Email  Stock Left  \
# 995  Mccoy, Austin and Padilla     gibsonjohn@woods-stone.org          15
# 996    Porter, Floyd and Craig          anthony50@jackson.com          41
# 997              Carroll Group        ugray@johnson-white.biz          50
# 998                  Lopez LLC  snydermegan@morris-hinton.com          20
# 999               Cox and Sons          margaret05@hanson.com          17
#
#     Auto Reorder Reorder Quantity
# 995           NO                0
# 996           NO                0
# 997           NO                0
# 998           NO                0
# 999           NO                0
#
# [5 rows x 25 columns]

# %%
# Finding Type
f'Data Type Is : {type(df)}'
# Out:
# "Data Type Is : <class 'pandas.core.frame.DataFrame'>"

# %%
# Finding data type in each columns
df.dtypes
# Out:
# Order ID             object
# Order Date           object
# Ship Date            object
# Customer ID          object
# Customer Name        object
# Customer Segment     object
# Product ID           object
# Product Name         object
# Category             object
# Region               object
# State                object
# City                 object
# Quantity              int64
# Unit Price            int64
# Discount (%)          int64
# Sales Amount        float64
# Cost Price          float64
# Profit              float64
# Payment Mode         object
# Delivery Status      object
# Supplier Name        object
# Supplier Email       object
# Stock Left            int64
# Auto Reorder         object
# Reorder Quantity      int64
# dtype: object

# %%
# Random sample from dataset
df.sample()
# Out:
#     Order ID  Order Date   Ship Date Customer ID Customer Name  \
# 836  ORD1836  2025-12-28  2026-01-03     CUST493   Sherri West
#
#     Customer Segment Product ID Product Name Category Region  ...  \
# 836         Consumer   PROD4848     Rice Bag  Grocery  South  ...
#
#     Sales Amount Cost Price    Profit  Payment Mode  Delivery Status  \
# 836      40932.0   29189.86  11742.14   Net Banking         Returned
#
#         Supplier Name            Supplier Email  Stock Left Auto Reorder  \
# 836  Singleton-Nguyen  qrogers@miller-lopez.org          27           NO
#
#     Reorder Quantity
# 836                0
#
# [1 rows x 25 columns]

# %%
# Finding summary of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          1000 non-null   object
#  1   Order Date        1000 non-null   object
#  2   Ship Date         1000 non-null   object
#  3   Customer ID       1000 non-null   object
#  4   Customer Name     1000 non-null   object
#  5   Customer Segment  1000 non-null   object
#  6   Product ID        1000 non-null   object
#  7   Product Name      1000 non-null   object
#  8   Category          1000 non-null   object
#  9   Region            1000 non-null   object
#  10  State             1000 non-null   object
#  11  City              1000 non-null   object
#  12  Quantity          1000 non-null   int64
#  13  Unit Price        1000 non-null   int64
#  14  Discount (%)      1000 non-null   int64
#  15  Sales Amount      1000 non-null   float64
#  16  Cost Price        1000 non-null   float64
#  17  Profit            1000 non-null   float64
#  18  Payment Mode      1000 non-null   object
#  19  Delivery Status   1000 non-null   object
#  20  Supplier Name     1000 non-null   object
#  21  Supplier Email    1000 non-null   object
#  22  Stock Left        1000 non-null   int64
#  23  Auto Reorder      1000 non-null   object
#  24  Reorder Quantity  1000 non-null   int64
# dtypes: float64(3), int64(5), object(17)
# memory usage: 195.4+ KB

# %%
# All columns name
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Customer ID', 'Customer Name',
#        'Customer Segment', 'Product ID', 'Product Name', 'Category', 'Region',
#        'State', 'City', 'Quantity', 'Unit Price', 'Discount (%)',
#        'Sales Amount', 'Cost Price', 'Profit', 'Payment Mode',
#        'Delivery Status', 'Supplier Name', 'Supplier Email', 'Stock Left',
#        'Auto Reorder', 'Reorder Quantity'],
#       dtype='object')

# %%
# Finding out the shape of dataset
f'There are total rows and column is : {df.shape}'
# Out:
# 'There are total rows and column is : (1000, 25)'

# %%
#Find discription of dataset
df.describe(include = "object")
# Out:
#        Order ID  Order Date   Ship Date Customer ID Customer Name  \
# count      1000        1000        1000        1000          1000
# unique     1000         553         548         614           993
# top     ORD1000  2025-01-05  2025-09-03     CUST302  Amy Gonzalez
# freq          1           7           6           7             2
#
#        Customer Segment Product ID  Product Name Category Region      State  \
# count              1000       1000          1000     1000   1000       1000
# unique                3        956            20        4      4         50
# top            Consumer   PROD1445  Office Chair  Grocery  South  Tennessee
# freq                350          3            64      255    277         36
#
#               City Payment Mode Delivery Status   Supplier Name  \
# count         1000         1000            1000            1000
# unique         976            4               4             965
# top     Robertstad         Cash       Delivered  Martinez Group
# freq             3          253             266               3
#
#                         Supplier Email Auto Reorder
# count                             1000         1000
# unique                            1000            1
# top     stewartjohn@johnson-moore.info           NO
# freq                                 1         1000

# %% [markdown]
# #Finding out null value

# %%
df.isnull().sum()
# Out:
# Order ID            0
# Order Date          0
# Ship Date           0
# Customer ID         0
# Customer Name       0
# Customer Segment    0
# Product ID          0
# Product Name        0
# Category            0
# Region              0
# State               0
# City                0
# Quantity            0
# Unit Price          0
# Discount (%)        0
# Sales Amount        0
# Cost Price          0
# Profit              0
# Payment Mode        0
# Delivery Status     0
# Supplier Name       0
# Supplier Email      0
# Stock Left          0
# Auto Reorder        0
# Reorder Quantity    0
# dtype: int64

# %% [markdown]
# Data Analysis

# %%
# Data quality check
print("\n DATA QUALITY ASSESSMENT")

# Check for missing values
print("\nMissing Value:")
missing_data = df.isnull().sum()
print(missing_data[missing_data > 0])

#Check for dublicates
print(f"\nDuplicate Row: {df.duplicated().sum()}")
# Out:
#  DATA QUALITY ASSESSMENT
#
# Missing Value:
# Series([], dtype: int64)
#
# Duplicate Row: 0

# %%
# Date type conversion
# Convert date columns to  datetime
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%Y-%m-%d')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='%Y-%m-%d')

print("\nDate columns converted")
print(f"Order Date: {df['Order Date'].dtype}")
print(f"Ship Date: {df['Ship Date'].dtype}")
# Out:
# Date columns converted
# Order Date: datetime64[ns]
# Ship Date: datetime64[ns]

# %%
# Univariate Analysis
print ('\n Categorical Variable\n')
categorical_cols = ['Customer Segment','Category','Region','Payment Mode', 'Delivery Status', 'Auto Reorder']
for col in categorical_cols:
    print(f'\n------{col}-----')
    print(df[col].value_counts())
# Out:
#  Categorical Variable
#
#
# ------Customer Segment-----
# Customer Segment
# Consumer        350
# Corporate       330
# House Office    320
# Name: count, dtype: int64
#
# ------Category-----
# Category
# Grocery            255
# Electronics        251
# Furniture          249
# Office Supplies    245
# Name: count, dtype: int64
#
# ------Region-----
# Region
# South    277
# West     243
# East     242
# North    238
# Name: count, dtype: int64
#
# ------Payment Mode-----
# Payment Mode
# Cash           253
# Credit Card    252
# Net Banking    250
# UPI            245
# Name: count, dtype: int64
#
# ------Delivery Status-----
# Delivery Status
# Delivered    266
# Cancelled    260
# Returned     245
# Pending      229
# Name: count, dtype: int64
#
# ------Auto Reorder-----
# Auto Reorder
# NO    1000
# Name: count, dtype: int64

# %%
# Visualization
for col in categorical_cols:
    print(f'\n------{col}-----')
    print(df[col].value_counts())
    plt.figure(figsize=(6,6))
    df[col].value_counts().plot(kind='bar',color='skyblue')
    plt.title(f"Distribution of {col}")
    plt.xticks(rotation = 30)
    plt.tight_layout()
    plt.show()
# Out:
# ------Customer Segment-----
# Customer Segment
# Consumer        350
# Corporate       330
# House Office    320
# Name: count, dtype: int64
# ------Category-----
# Category
# Grocery            255
# Electronics        251
# Furniture          249
# Office Supplies    245
# Name: count, dtype: int64
# ------Region-----
# Region
# South    277
# West     243
# East     242
# North    238
# Name: count, dtype: int64
# ------Payment Mode-----
# Payment Mode
# Cash           253
# Credit Card    252
# Net Banking    250
# UPI            245
# Name: count, dtype: int64
# ------Delivery Status-----
# Delivery Status
# Delivered    266
# Cancelled    260
# Returned     245
# Pending      229
# Name: count, dtype: int64
# ------Auto Reorder-----
# Auto Reorder
# NO    1000
# Name: count, dtype: int64

# %%
# Numerical variable analysis
print("\nNumerical Variables\n")
numerical_cols = ['Quantity','Unit Price','Discount (%)','Sales Amount','Cost Price','Profit','Stock Left', 'Reorder Quantity']

for col in numerical_cols:
    print(f'\n---{col}---\n')
    print(f'Mean: {df[col].mean():.2f}')
    print(f'Median: {df[col].median():.2f}')
    print(f'Std Dev:{df[col].std():.2f}')
    print(f'Min:{df[col].min():.2f}')
    print(f'Max:{df[col].max():.2f}')
# Out:
# Numerical Variables
#
#
# ---Quantity---
#
# Mean: 5.58
# Median: 6.00
# Std Dev:2.94
# Min:1.00
# Max:10.00
#
# ---Unit Price---
#
# Mean: 2579.78
# Median: 2613.50
# Std Dev:1417.04
# Min:100.00
# Max:4999.00
#
# ---Discount (%)---
#
# Mean: 9.93
# Median: 10.00
# Std Dev:7.13
# Min:0.00
# Max:20.00
#
# ---Sales Amount---
#
# Mean: 12739.41
# Median: 10030.10
# Std Dev:10348.36
# Min:120.00
# Max:49050.00
#
# ---Cost Price---
#
# Mean: 9517.78
# Median: 7331.53
# Std Dev:7823.45
# Min:77.71
# Max:40704.74
#
# ---Profit---
#
# Mean: 3221.63
# Median: 2311.97
# Std Dev:3001.15
# Min:18.50
# Max:16708.00
#
# ---Stock Left---
#
# Mean: 24.14
# Median: 24.00
# Std Dev:15.10
# Min:0.00
# Max:50.00
#
# ---Reorder Quantity---
#
# Mean: 0.00
# Median: 0.00
# Std Dev:0.00
# Min:0.00
# Max:0.00

# %%
# Numerical variable analysis
print("\nNumerical Variables\n")
numerical_cols = ['Quantity','Unit Price','Discount (%)','Sales Amount','Cost Price','Profit','Stock Left', 'Reorder Quantity']

for col in numerical_cols:
    print(f'\n---{col}---\n')
    print(f'Mean: {df[col].mean():.2f}')
    print(f'Median: {df[col].median():.2f}')
    print(f'Std Dev:{df[col].std():.2f}')
    print(f'Min:{df[col].min():.2f}')
    print(f'Max:{df[col].max():.2f}')
   #visualization
    plt.figure(figsize =(8,4))
    plt.subplot(1,2,1)
    df[col].hist(bins=30, color='lightgreen', alpha=0.7)
    plt.title(f'Distribution of {col}')

    plt.subplot(1,2,2)
    df.boxplot(column=col)
    plt.title(f'Boxplot of {col}')

    plt.tight_layout()
    plt.show()
# Out:
# Numerical Variables
#
#
# ---Quantity---
#
# Mean: 5.58
# Median: 6.00
# Std Dev:2.94
# Min:1.00
# Max:10.00
# ---Unit Price---
#
# Mean: 2579.78
# Median: 2613.50
# Std Dev:1417.04
# Min:100.00
# Max:4999.00
# ---Discount (%)---
#
# Mean: 9.93
# Median: 10.00
# Std Dev:7.13
# Min:0.00
# Max:20.00
# ---Sales Amount---
#
# Mean: 12739.41
# Median: 10030.10
# Std Dev:10348.36
# Min:120.00
# Max:49050.00
# ---Cost Price---
#
# Mean: 9517.78
# Median: 7331.53
# Std Dev:7823.45
# Min:77.71
# Max:40704.74
# ---Profit---
#
# Mean: 3221.63
# Median: 2311.97
# Std Dev:3001.15
# Min:18.50
# Max:16708.00
# ---Stock Left---
#
# Mean: 24.14
# Median: 24.00
# Std Dev:15.10
# Min:0.00
# Max:50.00
# ---Reorder Quantity---
#
# Mean: 0.00
# Median: 0.00
# Std Dev:0.00
# Min:0.00
# Max:0.00

# %%
#Bivariate Analysis
print('\n Sales & Profit by category\n')
category_performance = df.groupby('Category').agg({
    'Sales Amount': "sum",
    'Profit': 'sum',
    'Order ID':'count'}).rename(columns={'Order ID':'Order Count'})

category_performance['Profit Margin'] = (category_performance['Profit']/category_performance['Sales Amount'])*100
print(category_performance,'\n\n')

#Visualization
fig, axes = plt.subplots(2,2,figsize =(15,12))

#Sales by category
category_performance['Sales Amount'].plot(kind='bar', ax=axes[0,0], color='blue', alpha= 0.7)
axes[0,0].set_title('Total Sales by Category')
axes[0,0].tick_params(axis='x',rotation = 30)

#Sales by category
category_performance['Profit'].plot(kind='bar', ax=axes[0,1], color='green', alpha= 0.7)
axes[0,0].set_title('Total Profit by Category')
axes[0,0].tick_params(axis='x',rotation = 30)

#Sales by category
category_performance['Profit Margin'].plot(kind='bar', ax=axes[1,0], color='orange', alpha= 0.7)
axes[0,0].set_title('Profit Margin by Category(%)')
axes[0,0].tick_params(axis='x',rotation = 30)

#Sales by category
category_performance['Order Count'].plot(kind='bar', ax=axes[1,1], color='red', alpha= 0.7)
axes[0,0].set_title('Order count by Category')
axes[0,0].tick_params(axis='x',rotation = 30)

plt.tight_layout()
plt.show()
# Out:
#  Sales & Profit by category
#
#                  Sales Amount     Profit  Order Count  Profit Margin
# Category
# Electronics        3223808.90  816382.36          251      25.323535
# Furniture          3382752.55  832694.55          249      24.615887
# Grocery            3252088.45  825080.02          255      25.370774
# Office Supplies    2880762.35  747473.03          245      25.947056

# %%
#Regional Performance

# %%
print('\n===REGIONAL PERFORMANCE===\n')
regional_performance = df.groupby('Region').agg({
    'Sales Amount': 'sum',
    'Profit': 'sum',
    'Order ID':'count'
}).rename(columns={'Order ID' : 'Order Count'})
regional_performance['Profit Margin'] = (regional_performance['Profit']/ regional_performance['Sales Amount'])*100
print(regional_performance,'\n\n')

#Visualization
plt.figure(figsize=(12,8))

plt.subplot(2,2,1)
regional_performance['Sales Amount'].plot(kind='pie',autopct='%1.1f%%')
plt.title('Sales Distribution by Region')

plt.subplot(2,2,2)
regional_performance['Profit'].plot(kind='pie',autopct='%1.1f%%')
plt.title('Profit Distribution by Region')

plt.subplot(2,2,3)
sns.barplot(x=regional_performance.index, y='Order Count', data =regional_performance)
plt.title('Order Count by Region')
plt.xticks(rotation=30)

plt.subplot(2,2,4)
sns.barplot(x=regional_performance.index, y='Profit Margin', data =regional_performance)
plt.title('Profit Margin by Region(%)')
plt.xticks(rotation=30)

plt.tight_layout()
plt.show()
# Out:
# ===REGIONAL PERFORMANCE===
#
#         Sales Amount     Profit  Order Count  Profit Margin
# Region
# East      2928114.65  752764.52          242      25.708164
# North     3053728.00  781163.71          238      25.580658
# South     3466846.55  854508.35          277      24.648000
# West      3290723.05  833193.38          243      25.319462

# %%
print("\n=== TIME SERIES ANALYSIS ===\n")
# Extract time components
df['Order Month'] = df['Order Date'].dt.to_period('M')
df['Order Year'] = df['Order Date'].dt.year

# Monthly trends
monthly_trends = df.groupby('Order Month').agg({
    'Sales Amount' : 'sum',
    'Profit' : 'sum',
    'Order ID' : 'count'
}).rename(columns ={'Order ID' : 'Order Count'})

print("Monthly Trends:")
print(monthly_trends.tail(10),'\n\n')
# Out:
# === TIME SERIES ANALYSIS ===
#
# Monthly Trends:
#              Sales Amount     Profit  Order Count
# Order Month
# 2025-06         507218.40  141144.37           47
# 2025-07         538639.20  139160.23           45
# 2025-08         555391.95  143749.62           48
# 2025-09         435140.90  102698.39           36
# 2025-10         511539.45  123339.28           42
# 2025-11         523321.75  133197.21           46
# 2025-12         750582.20  201484.97           52
# 2026-01         454098.55  102174.53           38
# 2026-02         427831.20  106582.83           37
# 2026-03         153954.55   26498.45           10

# %%
print("\n=== TIME SERIES ANALYSIS ===\n")
# Extract time components
df['Order Month'] = df['Order Date'].dt.to_period('M')
df['Order Year'] = df['Order Date'].dt.year

# Monthly trends
monthly_trends = df.groupby('Order Month').agg({
    'Sales Amount' : 'sum',
    'Profit' : 'sum',
    'Order ID' : 'count'
}).rename(columns ={'Order ID' : 'Order Count'})

print("Monthly Trends:")
print(monthly_trends.tail(10),'\n\n')

# Visualization
plt.figure(figsize = (15,10))

plt.subplot(3,1,1)
monthly_trends['Sales Amount'].plot(kind = 'line', color='blue', marker = 'o')
plt.title('Monthly Sales Trend')
plt.ylabel('Sales Amount')
plt.grid(True)

plt.subplot(3,1,2)
monthly_trends['Profit'].plot(kind = 'line', color='green', marker = 'o')
plt.title('Monthly Profit Trend')
plt.ylabel('Profit')
plt.grid(True)

plt.subplot(3,1,3)
monthly_trends['Order Count'].plot(kind = 'line', color='red', marker = 'o')
plt.title('Monthly Order Count Trend')
plt.ylabel('Order Count')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# === TIME SERIES ANALYSIS ===
#
# Monthly Trends:
#              Sales Amount     Profit  Order Count
# Order Month
# 2025-06         507218.40  141144.37           47
# 2025-07         538639.20  139160.23           45
# 2025-08         555391.95  143749.62           48
# 2025-09         435140.90  102698.39           36
# 2025-10         511539.45  123339.28           42
# 2025-11         523321.75  133197.21           46
# 2025-12         750582.20  201484.97           52
# 2026-01         454098.55  102174.53           38
# 2026-02         427831.20  106582.83           37
# 2026-03         153954.55   26498.45           10

# %%
# Correlation Analysis
print("\n=== Correlation Analysis ===\n")

# Select numerical columns for correlation
numerical_df = df[['Quantity', 'Unit Price', 'Discount (%)', 'Sales Amount', 'Cost Price','Profit']]

# Correlation matrix
correlation_matrix = numerical_df.corr()
print('Correlation Matrix:')
print(correlation_matrix,'\n\n')

# Heatmap
plt.figure(figsize = (10 ,8))
sns.heatmap(correlation_matrix, annot = True,cmap='coolwarm', center=0, square = True, linewidths=0.5)
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()
# Out:
# === Correlation Analysis ===
#
# Correlation Matrix:
#               Quantity  Unit Price  Discount (%)  Sales Amount  Cost Price  \
# Quantity      1.000000   -0.053875      0.021379      0.629623    0.617583
# Unit Price   -0.053875    1.000000      0.005981      0.645014    0.639055
# Discount (%)  0.021379    0.005981      1.000000     -0.080171   -0.073878
# Sales Amount  0.629623    0.645014     -0.080171      1.000000    0.983747
# Cost Price    0.617583    0.639055     -0.073878      0.983747    1.000000
# Profit        0.561097    0.558193     -0.083853      0.883684    0.785271
#
#                 Profit
# Quantity      0.561097
# Unit Price    0.558193
# Discount (%) -0.083853
# Sales Amount  0.883684
# Cost Price    0.785271
# Profit        1.000000

# %%
print("\n=== CUSTOMER SEGMENT ANALYSIS ===\n")

segment_analysis = df.groupby('Customer Segment').agg({
    'Sales Amount': ['sum','mean'],
    'Profit': ['sum','mean'],
    'Order ID': 'count',
    'Discount (%)': 'mean'
}).round(2)

segment_analysis.columns = [
    'Total Sales',
    'Avg Sales',
    'Total Profit',
    'Avg Profit',
    'Order Count',
    'Avg Discount'
]

print(segment_analysis, '\n\n')

fig, axes = plt.subplots(2,2, figsize=(16,10))

segment_analysis['Total Sales'].plot(kind='bar', ax=axes[0,0], color='lightblue')
axes[0,0].set_title('Total Sales by Customer Segment')
axes[0,0].tick_params(axis='x', rotation=30)

segment_analysis['Total Profit'].plot(kind='bar', ax=axes[0,1], color='lightgreen')
axes[0,1].set_title('Total Profit by Customer Segment')
axes[0,1].tick_params(axis='x', rotation=30)

segment_analysis['Avg Profit'].plot(kind='bar', ax=axes[1,0], color='orange')
axes[1,0].set_title('Average Profit by Customer Segment')
axes[1,0].tick_params(axis='x', rotation=30)

segment_analysis['Avg Discount'].plot(kind='bar', ax=axes[1,1], color='red')
axes[1,1].set_title('Average Discount by Customer Segment')
axes[1,1].tick_params(axis='x', rotation=30)

plt.tight_layout()
plt.show()
# Out:
# === CUSTOMER SEGMENT ANALYSIS ===
#
#                   Total Sales  Avg Sales  Total Profit  Avg Profit  \
# Customer Segment
# Consumer           4306171.70   12303.35    1058060.59     3023.03
# Corporate          4224425.80   12801.29    1105519.88     3350.06
# House Office       4208814.75   13152.55    1058049.49     3306.40
#
#                   Order Count  Avg Discount
# Customer Segment
# Consumer                  350          9.80
# Corporate                 330          9.62
# House Office              320         10.38

# %%
print("\n=== KEY INSIGHTS SUMMARY ===")

# Overall Metrics
total_sales = df['Sales Amount'].sum()
total_profit = df['Profit'].sum()
total_orders = df['Order ID'].nunique()
avg_profit_margin = (total_profit / total_sales) * 100

print("\nOVERALL PERFORMANCE:\n")
print(f"Total Sales: ${total_sales:,.2f}")
print(f"Total Profit: ${total_profit:,.2f}")
print(f"Total Orders: {total_orders}")
print(f"Average Profit Margin: {avg_profit_margin:.2f}%")

# Top Performing Categories
top_categories = df.groupby('Category')['Profit'].sum().sort_values(ascending=False)

print("\nTOP PERFORMING CATEGORIES:\n")
for i, (category, profit) in enumerate(top_categories.items(), 1):
    print(f"{i}. {category}: ${profit:,.2f}")

# Regional Performance
best_region = df.groupby('Region')['Profit'].sum().idxmax()
print(f"\nBEST PERFORMING REGION: {best_region}")

# Delivery Performance
delivery_stats = df['Delivery Status'].value_counts(normalize=True) * 100
print("\nDELIVERY STATUS:")
for status, percentage in delivery_stats.items():
    print(f"{status}: {percentage:.1f}%")

# Customer Segments
best_segment = df.groupby('Customer Segment')['Profit'].sum().idxmax()
print(f"\nMOST PROFITABLE CUSTOMER SEGMENT: {best_segment}")
# Out:
# === KEY INSIGHTS SUMMARY ===
#
# OVERALL PERFORMANCE:
#
# Total Sales: $12,739,412.25
# Total Profit: $3,221,629.96
# Total Orders: 1000
# Average Profit Margin: 25.29%
#
# TOP PERFORMING CATEGORIES:
#
# 1. Furniture: $832,694.55
# 2. Grocery: $825,080.02
# 3. Electronics: $816,382.36
# 4. Office Supplies: $747,473.03
#
# BEST PERFORMING REGION: South
#
# DELIVERY STATUS:
# Delivered: 26.6%
# Cancelled: 26.0%
# Returned: 24.5%
# Pending: 22.9%
#
# MOST PROFITABLE CUSTOMER SEGMENT: Corporate

# %%
# EXPORT RESULT
print("\n=== EXPORT RESULTS ===")

analysis_results = {
    'total_sales': total_sales,
    'total_profit': total_profit,
    'total_orders': total_orders,
    'avg_profit_margin': avg_profit_margin,
    'top_category': top_categories.index[0],
    'best_region': best_region,
    'best_customer_segment': best_segment
}

# Convert to DataFrame
results_df = pd.DataFrame([analysis_results])

# Save to CSV
results_df.to_csv('analysis_summary.csv', index=False)

print("\nAnalysis summary saved to 'analysis_summary.csv'")
# Out:
# === EXPORT RESULTS ===
